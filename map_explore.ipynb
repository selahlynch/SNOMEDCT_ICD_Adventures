# %%
#Read in map and look at some stuff
import pandas as pd
import numpy as np
base_dir = "/Users/selah/Data/SnomedCT/SnomedCT_UStoICD10CM_20180301T120000Z/"
# %cd $base_dir
# Out:
# /Users/selah/Data/SnomedCT/SnomedCT_UStoICD10CM_20180301T120000Z

# %%
df = pd.read_csv('tls_Icd10cmHumanReadableMap_US1000124_20180301.tsv', sep='\t')

# %%
df
# Out:
#                                           id  effectiveTime  active  \
# 0       4c4d2755-e65f-52dc-8353-ecf437495eb8       20180301       1
# 1       f7e1ed02-3107-5a6c-9439-21e9879fb746       20180301       1
# 2       907aa2b0-a832-5254-acdf-6f366e406d2b       20180301       1
# 3       0b918513-be22-5059-beb6-e8348dfc631f       20180301       1
# 4       7f3f0a95-0441-57ba-a58f-03d2f2736c60       20180301       1
# 5       977608c1-d006-535a-93a7-7a7b75e90814       20180301       1
# 6       3fa74c85-56d0-5819-97e8-80c8d4c053c0       20180301       1
# 7       51537076-a3bf-59f8-aa5f-f571dfcf32cb       20180301       1
# 8       a0263a65-4056-5cf9-8caa-669afce20189       20180301       1
# 9       46693a5c-cef5-5634-8d3c-9f1af40de6fe       20180301       1
# 10      d63e09d0-6bbb-5684-a3e8-37caf50979b5       20180301       1
# 11      810fab38-5b41-5370-8637-1274d8ce25d3       20180301       1
# 12      eb1c05cc-e48f-5069-9d06-d6035462be0d       20180301       1
# ...

# %%
def getsnomeds(icd):
    return df[df.mapTarget==icd][['referencedComponentId','referencedComponentName']]

# %%
getsnomeds('K03.0')
# Out:
#         referencedComponentId  \
# 6                    10017004
# 5303                109582006
# 5304                109583001
# 5306                109584007
# 32217               196309004
# 55499               234977009
# 134804              404194009
# 140901               42141000
# 157171               48947008
# 159146               53042006
# 159632               53963006
# 159633               53963006
#
#                                   referencedComponentName
# 6                                  Occlusal wear of teeth
# 5303       Attrition of tooth crown associated with aging
# 5304    Attrition of tooth crown secondary to masticat...
# 5306                       Loss of teeth due to attrition
# 32217                               Approximal tooth wear
# 55499                                  Tooth surface loss
# 134804           Attrition of tooth due to teeth grinding
# 140901                           Approximal wear of teeth
# ...
